# %%
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd
from pandas import json_normalize

# %% [markdown]
# First API: EmojiHub https://emojihub.yurace.pro/api/all

# %%
res = requests.get("https://emojihub.yurace.pro/api/all")
res.status_code
# Out:
# 200

# %%
print(len(res.content))
print(res.content)
# Out:
# 255292
# ...

# %%
data = res.json()
df = json_normalize(data)
df.head()
# Out:
#                               name            category          group  \
# 0                    grinning face  smileys and people  face positive
# 1  grinning face with smiling eyes  smileys and people  face positive
# 2           face with tears of joy  smileys and people  face positive
# 3    rolling on the floor laughing  smileys and people  face positive
# 4     smiling face with open mouth  smileys and people  face positive
#
#       htmlCode    unicode
# 0  [&#128512;]  [U+1F600]
# 1  [&#128513;]  [U+1F601]
# 2  [&#128514;]  [U+1F602]
# 3  [&#129315;]  [U+1F923]
# 4  [&#128515;]  [U+1F603]

# %% [markdown]
# Second API: IMGFLIP https://api.imgflip.com/get_memes

# %%
res = requests.get("https://api.imgflip.com/get_memes")
res.status_code
# Out:
# 200

# %%
print(len(res.content))
print(res.content)
# Out:
# 14959
# ...

# %%
results = res.json()
results
# Out:
# {'success': True,
#  'data': {'memes': [{'id': '181913649',
#     'name': 'Drake Hotline Bling',
#     'url': 'https://i.imgflip.com/30b1gx.jpg',
#     'width': 1200,
#     'height': 1200,
#     'box_count': 2,
#     'captions': 1235500},
#    {'id': '87743020',
#     'name': 'Two Buttons',
#     'url': 'https://i.imgflip.com/1g8my4.jpg',
#     'width': 600,
#     'height': 908,
#     'box_count': 3,
#     'captions': 987750},
#    {'id': '112126428',
#     'name': 'Distracted Boyfriend',
#     'url': 'https://i.imgflip.com/1ur9b0.jpg',
#     'width': 1200,
#     'height': 800,
#     'box_count': 3,
#     'captions': 1019750},
#    {'id': '217743513',
#     'name': 'UNO Draw 25 Cards',
#     'url': 'https://i.imgflip.com/3lmzyx.jpg',
#     'width': 500,
#     'height': 494,
#     'box_count': 2,
#     'captions': 548750},
#    {'id': '131087935',
#     'name': 'Running Away Balloon',
#     'url': 'https://i.imgflip.com/261o3j.jpg',
#     'width': 761,
#     'height': 1024,
# ...

# %%
memes_data = results["data"]["memes"]

# %%
df = pd.DataFrame(memes_data)
df
# Out:
#            id                                               name  \
# 0   181913649                                Drake Hotline Bling
# 1    87743020                                        Two Buttons
# 2   112126428                               Distracted Boyfriend
# 3   217743513                                  UNO Draw 25 Cards
# 4   131087935                               Running Away Balloon
# ..        ...                                                ...
# 95  145139900                             Scooby doo mask reveal
# 96  478588645                            Borat 2 Tonight Queen??
# 97   92084495  Charlie Conspiracy (Always Sunny in Philidelphia)
# 98  177984372                What Gives People Feelings of Power
# 99  511654183                                        Sad Hamster
#
#                                  url  width  height  box_count  captions
# 0   https://i.imgflip.com/30b1gx.jpg   1200    1200          2   1235500
# ...

# %% [markdown]
# Third API: UselessFacts https://uselessfacts.jsph.pl//api/v2/facts/random

# %%
res = requests.get("https://uselessfacts.jsph.pl//api/v2/facts/random")
res.status_code
# Out:
# 200

# %%
print(len(res.content))
print(res.content)
# Out:
# 314
# b'{"id":"f3df402452c550993e46031dad9e698a","text":"Meteorologists claim they`re right 85% of the time (think about that one!)","source":"djtech.net","source_url":"http://www.djtech.net/humor/useless_facts.htm","language":"en","permalink":"https://uselessfacts.jsph.pl/api/v2/facts/f3df402452c550993e46031dad9e698a"}\n'

# %%
results = res.json()
results
# Out:
# {'id': 'f3df402452c550993e46031dad9e698a',
#  'text': 'Meteorologists claim they`re right 85% of the time (think about that one!)',
#  'source': 'djtech.net',
#  'source_url': 'http://www.djtech.net/humor/useless_facts.htm',
#  'language': 'en',
#  'permalink': 'https://uselessfacts.jsph.pl/api/v2/facts/f3df402452c550993e46031dad9e698a'}

# %%
df = json_normalize(results)
df
# Out:
#                                  id  \
# 0  f3df402452c550993e46031dad9e698a
#
#                                                 text      source  \
# 0  Meteorologists claim they`re right 85% of the ...  djtech.net
#
#                                       source_url language  \
# 0  http://www.djtech.net/humor/useless_facts.htm       en
#
#                                            permalink
# 0  https://uselessfacts.jsph.pl/api/v2/facts/f3df...
